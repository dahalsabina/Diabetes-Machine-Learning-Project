# %%
pip install import-ipynb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: import-ipynb in /home/LC/wollli02/.local/lib/python3.8/site-packages (0.1.4)
# Requirement already satisfied: nbformat in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from import-ipynb) (5.4.0)
# Requirement already satisfied: IPython in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from import-ipynb) (7.28.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from IPython->import-ipynb) (59.8.0)
# Requirement already satisfied: backcall in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from IPython->import-ipynb) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from IPython->import-ipynb) (3.0.30)
# Requirement already satisfied: pygments in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from IPython->import-ipynb) (2.13.0)
# Requirement already satisfied: pickleshare in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from IPython->import-ipynb) (0.18.1)
# Requirement already satisfied: traitlets>=4.2 in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from IPython->import-ipynb) (5.3.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: fastjsonschema in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from nbformat->import-ipynb) (2.16.1)
# Requirement already satisfied: jupyter-core in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from nbformat->import-ipynb) (4.11.1)
# Requirement already satisfied: jsonschema>=2.6 in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from nbformat->import-ipynb) (4.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (20.3.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.18.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0 in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (5.9.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->import-ipynb) (0.2.5)
# Requirement already satisfied: zipp>=3.1.0 in /opt/anaconda3/envs/ds420/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->import-ipynb) (3.8.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import GridSearchCV
import import_ipynb
import diabetes_training
from sklearn.metrics import mean_squared_error
import numpy as np
from diabetes_training import load_data, one_hot_encode, remove_outliers, standardize_data, prepare_data, split_train_dev_test
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import pandas as pd
# Out:
# importing Jupyter notebook from diabetes_training.ipynb
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 40 concurrent workers.
# convergence after 64 epochs took 2 seconds
# -- Epoch 1
# Norm: 11.60, NNZs: 16, Bias: -12.469790, T: 80000, Avg. loss: 0.183592
# Total training time: 0.01 seconds.
# [LibSVM]
# /opt/anaconda3/envs/ds420/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# Epoch 1, change: 1.00000000
# Epoch 2, change: 0.08726354
# Epoch 3, change: 0.04274949
# Epoch 4, change: 0.02766213
# Epoch 5, change: 0.02635183
# Epoch 6, change: 0.02095191
# Epoch 7, change: 0.01771921
# Epoch 8, change: 0.01605991
# Epoch 9, change: 0.01406865
# Epoch 10, change: 0.01248383
# Epoch 11, change: 0.01143417
# Epoch 12, change: 0.01029218
# Epoch 13, change: 0.00949221
# Epoch 14, change: 0.00852810
# Epoch 15, change: 0.00769081
# Epoch 16, change: 0.00705600
# Epoch 17, change: 0.00647130
# Epoch 18, change: 0.00581424
# Epoch 19, change: 0.00536393
# Epoch 20, change: 0.00483909
# Epoch 21, change: 0.00441604
# Epoch 22, change: 0.00405784
# Epoch 23, change: 0.00366573
# Epoch 24, change: 0.00337949
# Epoch 25, change: 0.00307534
# Epoch 26, change: 0.00281781
# Epoch 27, change: 0.00258303
# Epoch 28, change: 0.00232413
# Epoch 29, change: 0.00214576
# Epoch 30, change: 0.00195468
# Epoch 31, change: 0.00177914
# Epoch 32, change: 0.00162059
# Epoch 33, change: 0.00149571
# Epoch 34, change: 0.00137306
# Epoch 35, change: 0.00122884
# Epoch 36, change: 0.00112924
# Epoch 37, change: 0.00103572
# Epoch 38, change: 0.00094931
# Epoch 39, change: 0.00085739
# Epoch 40, change: 0.00078952
# Epoch 41, change: 0.00072447
# Epoch 42, change: 0.00065901
# Epoch 43, change: 0.00059795
# Epoch 44, change: 0.00054991
# Epoch 45, change: 0.00050041
# Epoch 46, change: 0.00046121
# Epoch 47, change: 0.00041595
# Epoch 48, change: 0.00038324
# Epoch 49, change: 0.00034760
# Epoch 50, change: 0.00032044
# Epoch 51, change: 0.00029091
# Epoch 52, change: 0.00026782
# Epoch 53, change: 0.00024616
# Epoch 54, change: 0.00021924
# Epoch 55, change: 0.00020453
# Epoch 56, change: 0.00018801
# Epoch 57, change: 0.00016663
# Epoch 58, change: 0.00015389
# Epoch 59, change: 0.00014152
# Epoch 60, change: 0.00013014
# Epoch 61, change: 0.00011970
# Epoch 62, change: 0.00010845
# Epoch 63, change: 0.00010037
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 2000
# obj = -3921.393394, rho = 0.594579
# nSV = 4000, nBSV = 4000
# Total nSV = 4000
# /opt/anaconda3/envs/ds420/lib/python3.8/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=2000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(

# %%
def grid_search_hyperparams(X_train, y_train):
 
    
    param_grid = {'C': [0.1, 1, 10, 100],  
              'gamma': [0.1, 0.01, 0.001], 
              'kernel': ['linear']} 
    
    print("Training ...")
    
    grid = GridSearchCV(SVC(),param_grid,
                        return_train_score=True,
                        refit=True, 
                        scoring='recall',
                        n_jobs=-1, 
                        cv=5,
                        verbose=3)
    grid.fit(X_train, y_train) 

    print("Grid searching is done!")
    print("The best score: ", grid.best_score_)
    print("The best hyperparameters:")
    print(grid.best_params_)
    return grid

# %%
def main():
   
    X, y = load_data()
    
    columns_to_encode = ['gender', 'smoking_history']
    columns_to_scale = ['age', 'bmi', 'HbA1c_level', 'blood_glucose_level']
    columns_no_scale = ['hypertension', 'heart_disease']
    
    X_prepared = prepare_data(X, columns_to_encode, columns_to_scale, columns_no_scale)
    
    X_train, X_dev, X_test, y_train, y_dev, y_test = split_train_dev_test(X_prepared, y)
    
    
    best_model = grid_search_hyperparams(X_train, y_train)
    
   
    final_predictions = best_model.predict(X_test)
    
    
    accuracy = accuracy_score(y_test, final_predictions)
    precision = precision_score(y_test, final_predictions, average='macro')
    recall = recall_score(y_test, final_predictions, average='macro')
    f1 = f1_score(y_test, final_predictions, average='macro')

    print("Accuracy: ", accuracy)
    print("Precision: ", precision)
    print("Recall: ", recall)
    print("F1 Score: ", f1)
    
    return best_model

main()
# Out:
# Training ...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Grid searching is done!
# The best score:  0.5923218716767105
# The best hyperparameters:
# {'C': 100, 'gamma': 0.1, 'kernel': 'linear'}
# Accuracy:  0.9612
# Precision:  0.9419242831541219
# Recall:  0.8013793630245478
# F1 Score:  0.8555650058726971
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'gamma': [0.1, 0.01, 0.001],
#                          'kernel': ['linear']},
#              return_train_score=True, scoring='recall', verbose=3)
# [CV 3/5] END C=1, gamma=0.1, kernel=rbf;, score=(train=0.565, test=0.553) total time= 1.3min
# [CV 2/5] END C=0.1, gamma=0.1, kernel=linear;, score=(train=0.568, test=0.573) total time= 1.0min
# [CV 1/5] END C=1, gamma=0.01, kernel=rbf;, score=(train=0.521, test=0.534) total time= 1.7min
# [CV 1/5] END C=0.1, gamma=0.001, kernel=linear;, score=(train=0.566, test=0.573) total time= 1.0min
# [CV 5/5] END C=10, gamma=0.01, kernel=rbf;, score=(train=0.578, test=0.574) total time= 1.4min
# [CV 2/5] END C=0.1, gamma=0.01, kernel=linear;, score=(train=0.568, test=0.573) total time= 1.0min
# [CV 5/5] END C=0.1, gamma=0.01, kernel=rbf;, score=(train=0.104, test=0.110) total time= 2.0min
# [CV 1/5] END C=1, gamma=0.001, kernel=linear;, score=(train=0.588, test=0.593) total time= 1.1min
# [CV 2/5] END C=1, gamma=0.1, kernel=rbf;, score=(train=0.563, test=0.566) total time= 1.3min
# [CV 5/5] END C=0.1, gamma=0.1, kernel=linear;, score=(train=0.569, test=0.568) total time= 1.0min
# [CV 1/5] END C=0.1, gamma=0.001, kernel=rbf;, score=(train=0.000, test=0.000) total time= 2.0min
# [CV 5/5] END C=1, gamma=0.01, kernel=linear;, score=(train=0.589, test=0.586) total time= 1.1min
# [CV 2/5] END C=10, gamma=0.01, kernel=rbf;, score=(train=0.578, test=0.582) total time= 1.3min
# [CV 4/5] END C=0.1, gamma=0.01, kernel=linear;, score=(train=0.567, test=0.561) total time= 1.0min
# [CV 4/5] END C=0.1, gamma=0.001, kernel=rbf;, score=(train=0.000, test=0.000) total time= 2.0min
# [CV 5/5] END C=1, gamma=0.1, kernel=linear;, score=(train=0.589, test=0.586) total time= 1.1min
# [CV 4/5] END C=1, gamma=0.01, kernel=rbf;, score=(train=0.521, test=0.519) total time= 1.7min
# [CV 5/5] END C=0.1, gamma=0.001, kernel=linear;, score=(train=0.569, test=0.568) total time= 1.1min
# [CV 3/5] END C=0.1, gamma=0.1, kernel=rbf;, score=(train=0.508, test=0.497) total time= 1.7min
# [CV 1/5] END C=1, gamma=0.1, kernel=linear;, score=(train=0.588, test=0.593) total time= 1.1min
# [CV 5/5] END C=0.1, gamma=0.001, kernel=rbf;, score=(train=0.000, test=0.000) total time= 2.1min
# [CV 3/5] END C=10, gamma=0.1, kernel=linear;, score=(train=0.598, test=0.585) total time= 1.2min
# [CV 3/5] END C=10, gamma=0.1, kernel=rbf;, score=(train=0.585, test=0.570) total time= 1.2min
# [CV 4/5] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.523, test=0.520) total time=  57.9s
# [CV 4/5] END C=10, gamma=0.01, kernel=linear;, score=(train=0.592, test=0.589) total time= 1.2min
# [CV 5/5] END C=10, gamma=0.1, kernel=rbf;, score=(train=0.580, test=0.562) total time= 1.3min
# [CV 5/5] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.527, test=0.514) total time=  58.3s
# [CV 5/5] END C=10, gamma=0.01, kernel=linear;, score=(train=0.593, test=0.587) total time= 1.2min
# [CV 3/5] END C=1, gamma=0.001, kernel=rbf;, score=(train=0.122, test=0.119) total time= 2.1min
# [CV 5/5] END C=10, gamma=0.1, kernel=linear;, score=(train=0.593, test=0.587) total time= 1.2min
# [CV 4/5] END C=0.1, gamma=0.01, kernel=rbf;, score=(train=0.108, test=0.095) total time= 2.1min
# [CV 4/5] END C=10, gamma=0.1, kernel=linear;, score=(train=0.592, test=0.589) total time= 1.3min
# [CV 2/5] END C=0.1, gamma=0.01, kernel=rbf;, score=(train=0.104, test=0.108) total time= 2.0min
# [CV 1/5] END C=10, gamma=0.1, kernel=linear;, score=(train=0.592, test=0.595) total time= 1.2min
# [CV 4/5] END C=10, gamma=0.1, kernel=rbf;, score=(train=0.578, test=0.574) total time= 1.2min
# [CV 2/5] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.521, test=0.533) total time=  55.8s
# [CV 2/5] END C=10, gamma=0.01, kernel=linear;, score=(train=0.589, test=0.602) total time= 1.3min
# [CV 2/5] END C=10, gamma=0.1, kernel=rbf;, score=(train=0.578, test=0.582) total time= 1.2min
# [CV 3/5] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.524, test=0.511) total time=  59.0s
# [CV 3/5] END C=10, gamma=0.01, kernel=linear;, score=(train=0.598, test=0.585) total time= 1.3min
# [CV 4/5] END C=1, gamma=0.001, kernel=rbf;, score=(train=0.123, test=0.106) total time= 2.1min
# [CV 2/5] END C=10, gamma=0.1, kernel=linear;, score=(train=0.589, test=0.602) total time= 1.3min
# [CV 1/5] END C=10, gamma=0.1, kernel=rbf;, score=(train=0.576, test=0.589) total time= 1.2min
# [CV 1/5] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.523, test=0.534) total time=  55.5s
# [CV 1/5] END C=10, gamma=0.01, kernel=linear;, score=(train=0.592, test=0.595) total time= 1.3min
# [CV 2/5] END C=0.1, gamma=0.001, kernel=rbf;, score=(train=0.000, test=0.000) total time= 2.1min
# [CV 4/5] END C=1, gamma=0.01, kernel=linear;, score=(train=0.589, test=0.583) total time=  56.3s
# [CV 4/5] END C=10, gamma=0.001, kernel=linear;, score=(train=0.592, test=0.589) total time=  44.6s
# [CV 5/5] END C=1, gamma=0.01, kernel=rbf;, score=(train=0.526, test=0.513) total time= 1.7min
# [CV 2/5] END C=1, gamma=0.1, kernel=linear;, score=(train=0.587, test=0.600) total time=  57.0s
# [CV 3/5] END C=10, gamma=0.001, kernel=linear;, score=(train=0.598, test=0.585) total time=  46.6s
# [CV 2/5] END C=0.1, gamma=0.1, kernel=rbf;, score=(train=0.506, test=0.517) total time= 1.8min
# [CV 3/5] END C=1, gamma=0.01, kernel=linear;, score=(train=0.595, test=0.579) total time=  53.4s
# [CV 1/5] END C=10, gamma=0.001, kernel=linear;, score=(train=0.592, test=0.595) total time=  50.3s
# [CV 2/5] END C=1, gamma=0.01, kernel=rbf;, score=(train=0.520, test=0.531) total time= 1.7min
# [CV 4/5] END C=1, gamma=0.1, kernel=linear;, score=(train=0.589, test=0.583) total time=  54.8s
# [CV 2/5] END C=10, gamma=0.001, kernel=linear;, score=(train=0.589, test=0.602) total time=  50.1s
# [CV 2/5] END C=1, gamma=0.001, kernel=rbf;, score=(train=0.120, test=0.121) total time= 2.0min
# [CV 4/5] END C=1, gamma=0.001, kernel=linear;, score=(train=0.589, test=0.583) total time=  55.4s
# [CV 5/5] END C=10, gamma=0.001, kernel=linear;, score=(train=0.593, test=0.587) total time=  51.3s
# [CV 4/5] END C=0.1, gamma=0.1, kernel=rbf;, score=(train=0.507, test=0.505) total time= 1.7min
# [CV 2/5] END C=0.1, gamma=0.001, kernel=linear;, score=(train=0.568, test=0.573) total time=  56.3s
# [CV 3/5] END C=100, gamma=0.1, kernel=linear;, score=(train=0.598, test=0.585) total time= 1.2min
# [CV 3/5] END C=0.1, gamma=0.01, kernel=rbf;, score=(train=0.109, test=0.102) total time= 2.1min
# [CV 5/5] END C=1, gamma=0.001, kernel=linear;, score=(train=0.589, test=0.586) total time=  59.2s
# [CV 2/5] END C=100, gamma=0.01, kernel=linear;, score=(train=0.590, test=0.602) total time= 1.1min
# [CV 1/5] END C=0.1, gamma=0.01, kernel=rbf;, score=(train=0.105, test=0.114) total time= 1.8min
# [CV 2/5] END C=1, gamma=0.001, kernel=linear;, score=(train=0.587, test=0.600) total time=  58.6s
# [CV 1/5] END C=100, gamma=0.1, kernel=linear;, score=(train=0.592, test=0.597) total time= 1.2min
# [CV 1/5] END C=10, gamma=0.01, kernel=rbf;, score=(train=0.577, test=0.585) total time= 1.4min
# [CV 5/5] END C=0.1, gamma=0.01, kernel=linear;, score=(train=0.569, test=0.568) total time=  57.4s
# [CV 5/5] END C=100, gamma=0.1, kernel=linear;, score=(train=0.594, test=0.587) total time= 1.2min
# [CV 5/5] END C=0.1, gamma=0.1, kernel=rbf;, score=(train=0.510, test=0.500) total time= 1.7min
# [CV 3/5] END C=0.1, gamma=0.001, kernel=linear;, score=(train=0.569, test=0.561) total time=  59.0s
# [CV 4/5] END C=100, gamma=0.01, kernel=linear;, score=(train=0.592, test=0.590) total time= 1.2min
# [CV 1/5] END C=1, gamma=0.001, kernel=rbf;, score=(train=0.122, test=0.128) total time= 2.0min
# [CV 1/5] END C=1, gamma=0.01, kernel=linear;, score=(train=0.588, test=0.593) total time= 1.0min
# [CV 4/5] END C=100, gamma=0.001, kernel=linear;, score=(train=0.592, test=0.590) total time= 1.2min
# [CV 3/5] END C=1, gamma=0.01, kernel=rbf;, score=(train=0.523, test=0.510) total time= 1.6min
# [CV 4/5] END C=0.1, gamma=0.001, kernel=linear;, score=(train=0.567, test=0.561) total time=  58.6s
# [CV 1/5] END C=100, gamma=0.01, kernel=linear;, score=(train=0.592, test=0.597) total time= 1.2min
# [CV 1/5] END C=0.1, gamma=0.1, kernel=rbf;, score=(train=0.506, test=0.515) total time= 1.7min
# [CV 3/5] END C=1, gamma=0.1, kernel=linear;, score=(train=0.595, test=0.579) total time=  57.5s
# [CV 2/5] END C=100, gamma=0.1, kernel=linear;, score=(train=0.590, test=0.602) total time= 1.2min
# [CV 4/5] END C=10, gamma=0.01, kernel=rbf;, score=(train=0.577, test=0.574) total time= 1.4min
# [CV 3/5] END C=0.1, gamma=0.01, kernel=linear;, score=(train=0.569, test=0.561) total time=  57.1s
# [CV 4/5] END C=100, gamma=0.1, kernel=linear;, score=(train=0.592, test=0.590) total time= 1.2min
# [CV 3/5] END C=0.1, gamma=0.001, kernel=rbf;, score=(train=0.000, test=0.000) total time= 2.0min
# [CV 3/5] END C=1, gamma=0.001, kernel=linear;, score=(train=0.595, test=0.579) total time=  59.2s
# [CV 3/5] END C=100, gamma=0.01, kernel=linear;, score=(train=0.598, test=0.585) total time= 1.2min
# [CV 5/5] END C=1, gamma=0.001, kernel=rbf;, score=(train=0.117, test=0.126) total time= 2.0min
# [CV 2/5] END C=1, gamma=0.01, kernel=linear;, score=(train=0.587, test=0.600) total time= 1.0min
# [CV 5/5] END C=100, gamma=0.01, kernel=linear;, score=(train=0.594, test=0.587) total time= 1.2min
# [CV 1/5] END C=1, gamma=0.1, kernel=rbf;, score=(train=0.558, test=0.573) total time= 1.3min
# [CV 3/5] END C=0.1, gamma=0.1, kernel=linear;, score=(train=0.569, test=0.561) total time= 1.0min
# [CV 2/5] END C=100, gamma=0.001, kernel=linear;, score=(train=0.590, test=0.602) total time= 1.2min
# [CV 5/5] END C=1, gamma=0.1, kernel=rbf;, score=(train=0.566, test=0.554) total time= 1.3min
# [CV 1/5] END C=0.1, gamma=0.01, kernel=linear;, score=(train=0.566, test=0.573) total time= 1.0min
# [CV 1/5] END C=100, gamma=0.001, kernel=linear;, score=(train=0.592, test=0.597) total time= 1.3min
# [CV 4/5] END C=1, gamma=0.1, kernel=rbf;, score=(train=0.561, test=0.557) total time= 1.3min
# [CV 1/5] END C=0.1, gamma=0.1, kernel=linear;, score=(train=0.566, test=0.573) total time= 1.0min
# [CV 3/5] END C=100, gamma=0.001, kernel=linear;, score=(train=0.598, test=0.585) total time= 1.3min
# [CV 3/5] END C=10, gamma=0.01, kernel=rbf;, score=(train=0.580, test=0.568) total time= 1.3min
# [CV 4/5] END C=0.1, gamma=0.1, kernel=linear;, score=(train=0.567, test=0.561) total time= 1.0min
# [CV 5/5] END C=100, gamma=0.001, kernel=linear;, score=(train=0.594, test=0.587) total time= 1.3min
